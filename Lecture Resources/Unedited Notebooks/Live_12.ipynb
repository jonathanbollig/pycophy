# %%
import scipy 
import scipy.constants as c
import numpy as np

# %matplotlib widget
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (4,3)
plt.rcParams["axes.grid"] = True

# %%
x = np.linspace(0, 10, 100)
y_theory = 0.75 * x**2 - 4.5*x - 33
y_measurement = y_theory + 12*(np.random.rand(len(x)) - 0.5)

plt.plot(x, y_measurement, marker="x", linestyle="")
plt.show()

# %%
coeffs = np.polyfit(x, y, 2)
print(coeffs)
y_fit = coeffs[0] * x**2 + coeffs[1] * x + coeffs[2]

plt.plot(x, y, marker="x", linestyle="")
plt.plot(x, y_fit)
plt.plot(x, y_theory);
# Out:
# [  0.76915845  -4.64665524 -33.37330444]
