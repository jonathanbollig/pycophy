# %%
name = "Emil"

if 
    # print("The name is Emil")
if 
    # print("The name is not Emil")

# later "Emil" --> "Dieter"

# %%
your_age = 12

if 
    # print("You can buy cigarettes")
if 
    # print("You can not buy cigarettes")

# later 12 --> 99

# %%
# user input

# string conversion

# age example with user input
