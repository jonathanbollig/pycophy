# %%
import numpy as np

my_list = [[1, 2, 3], 
           [4, 5, 6]]
my_array = np.array(my_list)

my_array = np.array([[1, 2, 3], 
                     [4, 5, 6]])

another_array = np.zeros((5, 5))

# %%
# indexing
# without coma --> first dimension

# coma access next dimension

# %%
# slicing
# first dimension

# second dimension

# : without more

# %%
# Useful stuff

# transpose

# flatten

# concatenate(())

# %%
# imshow
import matplotlib.pyplot as plt
random_matrix = np.random.random((10, 10))

# plot

# imshow

# title

# colorbar
