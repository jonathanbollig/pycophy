# %%
# normal import
# import math

# print(math.sqrt(2))
# from import
# from math import sqrt
# print(sqrt(2))

# multiple from import
# print(sin(2))

# import all

# rename on import 
from math import sqrt as sq
sq(2)

# Use conda install scipy as example
import scipy
