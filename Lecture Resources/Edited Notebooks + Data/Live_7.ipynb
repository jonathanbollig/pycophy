# %%
# no planned live coding but in case I decide other wise

# normal import

# from import

# multiple from import

# import all

# rename on import 

# Use conda install scipy as example
