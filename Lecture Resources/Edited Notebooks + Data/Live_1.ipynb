# %% [markdown]
# *Create Markdown here*

# %%
# create code

# %% [markdown]
# *create markdown header, list, bold etc*

# %%
# print a string

# print a number (incl. calculation)

# %%
# create an error (zero division)
