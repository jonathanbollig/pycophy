# %%
# Print statement with string

# %%
# Print statement with number (int / float)

# %%
# Saving Data into memory

# %%
# comments (single line and multiline)

# %%
# Variable Names

# %%
this_is_a_string = "Hello Mars"
this_is_a_int = 10
this_is_a_float = 9.31
this_is_a_boolean = True
this_is_no_value = None
print(this_is_a_string)
print(this_is_a_int)
print(this_is_a_float)
print(this_is_a_boolean)
print(this_is_no_value)
# print empty line

# print multiple with coma

# %%
# Memory, exist without assignment status

# %%
# Deleting Memory --> Restarting Kernel --> Error

# %%
# Arithmetic Operators
# Example int

# Adding to itself

# Operators on String

# %%
# Type Parsing

# the type() Operator

# Converting "1" to different types

# Example for not possible type conversion

# %%
# show print int + str does not work

# concat int and str for print

# %%
# automatic type parsing example with type() (int --> float)
