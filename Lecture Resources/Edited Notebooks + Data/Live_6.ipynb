# %%
# single input: print double
def print_double(data):
    print(data)
    print(data)

print_double("hi")
print_double("Good Morning")
# Out:
# hi
# hi
# Good Morning
# Good Morning

# %%
# multiple input: calculate radius
def calculate_radius(x, y):
    r = (x**2 + y**2)**(1/2)
    print(r)

calculate_radius(10, 5)
# Out:
# 11.180339887498949

# %%
# single return: calculate radius
def calculate_radius(x, y):
    r = (x**2 + y**2)**(1/2)
    return r
    print("Hiiiiii")

radius = calculate_radius(10, 5)
radius1 = calculate_radius(11, 5)
print(radius+radius1)
print(2)
# Out:
# 23.26338586109352
# 2

# %%
# multiple return: cartesian_to_polar
from math import sqrt, atan2

#     r = sqrt(x**2 + y**2)
#     phi = atan2(x, y)

# %%
# maybe improvise something about variable scope
# print variable that is defined outside the function

# overwrite it inside the function

# call it outside
