# %%
import matplotlib.pyplot as plt
plt.plot([0, 1])
plt.show()

# %%
# two types
import numpy as np
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# only y data
# plt.plot(y)
# plt.show()

# y and x data
# plt.plot(x, y)
# plt.show()

# %%
# More data
y2 = np.cos(x)

# plot both

# add axis labels

# add grid

# add title

# add label

# change c

# change linestyle

# mention scatter
