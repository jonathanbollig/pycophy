# %%
measurement_1 = 3.13
measurement_2 = 5.83
measurement_3 = 7.22

# %%
# better way:
measurements =

# %%
# list contains different things
cool_list =

# %%
# list contains a list
cool_list2 =

# %%
my_list = [100, 50, 0, 99, 4, 42]
# print, print+index

# index from back

# slicing

# from beginning / end

# complete list

# %%
my_list = [100, 50, 0, 99, 4, 42]
# change element in list

# change multiple elements in list

# %%
list1 = [1, 2, 3, 4]
list2 = ["a", "b", "c"]

# arithmetic operators on lists

# +

# *

# len

# %%
my_list = [100, 50, 0, 99, 4, 42]
# append

# min 

# max

# sum
