# %% [markdown]
# # Example Notebook

# %%
# This is a code cell. It can execute code:
print("Hello everyone :)")
print(2+2)
# Out:
# Hello everyone :)
# 4

# %% [markdown]
# This is an example notebook. Execute it, to check if everything works.
#
# This is a markdown cell

# %% [markdown]
# # A Big Header
# ## A smaller header
# ### A even smaller header
#
# Some text
#
# Some more text
#
# A list of stuff:
# - first stuff
# - second stuff
# - third stuff

# %%
a = 10
print(a)
# Out:
# 10
