# %% [markdown]
# # Tasks for Reading and Writing Files

# %% [markdown]
# ## <span style="background-color: #bbdefb; color: black; padding: 2px 5px; border-radius: 3px;">Cheat-Sheet</span>
# A summary of what you have learned in the last chunk. Collapse this part on the left side, if you want to hide the cheat sheet.

# %% [markdown]
# **Reading data** from text files (like `.csv` or `.txt`) is a fundamental task. While `numpy.loadtxt` works for simple cases, it can be tricky. A more powerful and flexible method is to use the **Pandas** library, which is designed for tabular data.

# %%
# %matplotlib widget
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# The main function is `pd.read_table()`. We use `.to_numpy()` at the end to get a standard NumPy array that we can work with.

# %%
# The file path is relative to where your notebook is running
# 'data/...' means look inside the 'data' folder for the file.
filepath = "data/daily_temperature.txt"

# Common arguments:
# sep='\\s+'  -> separator is one or more whitespace characters
# delimiter=',' -> separator is a comma
# skiprows=N   -> skip the first N lines (e.g., headers)
# header=None  -> treat the first row as data, not column names

# Example for the temperature data, which has a 22-line header:
# data = pd.read_csv(filepath, sep='\\s+', skiprows=22, header=None).to_numpy()

# %% [markdown]
# **Paths** can be **relative** (from your current code's location) or **absolute** (the full path from your computer's root directory)[cite: 55, 59]. [cite_start]You can find your **Current Working Directory (CWD)** using the `os` module.

# %%
print(f"My Current Working Directory is: {os.getcwd()}")
# Out:
# My Current Working Directory is: D:\OneDrive - Friedrich-Schiller-Universität Jena\Arbeit\2025 Python Course\pycophy\Task Sheets

# %% [markdown]
# **Saving a NumPy array** to a human-readable text file is done with `np.savetxt()`.

# %%
my_data = np.array([[1, 2.345], [3, 4.567]])

# np.savetxt('output.csv', my_data, delimiter=',', fmt='%.3f', header='Col1,Col2')
# fmt='%.3f' saves numbers as floats with 3 decimal places

# %% [markdown]
# Saving a NumPy array to a **binary** (not human-readable file) can be done with `np.save()`. Loading is done by `np.load()`.

# %% [markdown]
# ## <span style="background-color: #bbdefb; color: black; padding: 2px 5px; border-radius: 3px;">Core Tasks</span>
# You should be able to do these tasks within the given time. Please try to solve them to follow the next topics of the course.

# %% [markdown]
# ### Code Creation

# %% [markdown]
# <span style="background-color: #f8bbd0; color: black; padding: 2px 5px; border-radius: 3px;">**Task 11.2**</span> Load the data from `data/daily_temperature.txt` into a NumPy array called `avg_temp_data`. Print the `.shape` of the resulting array to see how much data you've loaded. Check the lecture slides, if you don't manage.

# %%
# Your solution here

# %% [markdown]
# <span style="background-color: #f8bbd0; color: black; padding: 2px 5px; border-radius: 3px;">**Task 11.3**</span> To avoid repeating code, write a Python **function** `load_temp_data(filename)` that takes a filename (e.g., `daily_temperature.txt`) as input. The function should:
# 1. Construct the full relative path (e.g., `data/filename`).
# 2. Load the data using pandas, skipping the 22 header rows.
# 3. Convert it to a NumPy array.
# 4. **Return** the NumPy array.
#
# Test your function by loading `daily_temperature_high.txt` and `daily_temperature_low.txt`.

# %%
# Your solution here

# %% [markdown]
# <span style="background-color: #f8bbd0; color: black; padding: 2px 5px; border-radius: 3px;">**Task 11.4**</span> The data is currently a 2D array containing pairs of `year` and `anomaly`. Because the use is easier, extract the values in 1D arrays **year** (column 0) and the **temperature anomaly** (column 1).
#
# Using the `avg_temp_data` array you loaded earlier, use NumPy **slicing** to extract these two columns. Store them in new 1D arrays called `years` and `anomalies`.

# %%
# Your solution here

# %% [markdown]
# <span style="background-color: #f8bbd0; color: black; padding: 2px 5px; border-radius: 3px;">**Task 11.5**</span> Now, let's visualize the results! Create a **plot** of the `anomalies` (y-axis) vs. the `years` (x-axis). Add a title, axis labels, and a grid to make the plot clear and informative. The plot should be interactive due to the line magic `%matplotlib widget` at the beginning.

# %%
# Your solution here

# %% [markdown]
# <span style="background-color: #f8bbd0; color: black; padding: 2px 5px; border-radius: 3px;">**Task 11.6**</span> You have now extracted the most important information. Create a new 2D NumPy array called `cleaned_data` that contains just two columns: the `years` and the `anomalies`.
#
# Then, **save** this `cleaned_data` to a new file named `cleaned_temperature_data.csv` inside the `data` folder. Use a comma as the delimiter and format the numbers to have 4 decimal places.

# %%
# Your solution here

# %% [markdown]
# ## <span style="background-color: #bbdefb; color: black; padding: 2px 5px; border-radius: 3px;">Optional Tasks</span>
# If you are fast, you can continue with these optional tasks for some extra practice.

# %% [markdown]
# <span style="background-color: #f8bbd0; color: black; padding: 2px 5px; border-radius: 3px;">**Task 11.7**</span> Plot the `high`, `avg`, and `low` temperature anomalies all on the same graph.
#
# - Use `label` for each plot and add a `legend`.
# - *Hint:* You can use the `alpha` argument in `plt.plot()` (e.g., `alpha=0.5`) to make lines semi-transparent.
# - Note: Averaging would be smart here, but this is not covered yet.

# %%
# Your solution here

# %% [markdown]
# ## <span style="background-color: #bbdefb; color: black; padding: 2px 5px; border-radius: 3px;">Advanced Topics & Tasks</span>
# This part introduces some new concepts and according tasks. Do them if you are superfast, or later if you want to learn more.

# %% [markdown]
# This is empty as of now. Maybe I will fill it later
